# %%
from google.colab import drive
drive.mount('/content/drive')

project_path = "/content/drive/MyDrive/Data_Science_Projects/Customer_Complaint_Trend_Forecasting/"
data_path = project_path + "data/"

# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !pip install pyspark --quiet

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/usr/local/lib/python3.12/dist-packages/pyspark"

from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Cleaner").getOrCreate()

print("Spark ready.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Spark ready.

# %%
df = spark.read.option("header", True).option("inferSchema", True).csv(data_path + "complaints_raw.csv")

print("RAW COLUMNS:")
for c in df.columns:
    print(repr(c))

df.printSchema()
# Out:
# RAW COLUMNS:
# 'Date received'
# 'Product'
# 'Sub-product'
# 'Issue'
# 'Sub-issue'
# 'Consumer complaint narrative'
# 'Company public response'
# 'Company'
# 'State'
# 'ZIP code'
# 'Tags'
# 'Consumer consent provided?'
# 'Submitted via'
# 'Date sent to company'
# 'Company response to consumer'
# 'Timely response?'
# 'Consumer disputed?'
# 'Complaint ID'
# root
#  |-- Date received: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Sub-product: string (nullable = true)
#  |-- Issue: string (nullable = true)
#  |-- Sub-issue: string (nullable = true)
#  |-- Consumer complaint narrative: string (nullable = true)
#  |-- Company public response: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIP code: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Consumer consent provided?: string (nullable = true)
#  |-- Submitted via: string (nullable = true)
#  |-- Date sent to company: string (nullable = true)
#  |-- Company response to consumer: string (nullable = true)
#  |-- Timely response?: string (nullable = true)
#  |-- Consumer disputed?: string (nullable = true)
#  |-- Complaint ID: string (nullable = true)

# %%
from pyspark.sql.functions import col, trim, length

text_col = "Consumer complaint narrative"

df = df.dropna(subset=[text_col])
df = df.filter(length(trim(col(text_col))) > 0)

print("AFTER TEXT DROP:")
for c in df.columns:
    print(repr(c))
# Out:
# AFTER TEXT DROP:
# 'Date received'
# 'Product'
# 'Sub-product'
# 'Issue'
# 'Sub-issue'
# 'Consumer complaint narrative'
# 'Company public response'
# 'Company'
# 'State'
# 'ZIP code'
# 'Tags'
# 'Consumer consent provided?'
# 'Submitted via'
# 'Date sent to company'
# 'Company response to consumer'
# 'Timely response?'
# 'Consumer disputed?'
# 'Complaint ID'

# %%
from pyspark.sql import functions as F

spark.conf.set("spark.sql.legacy.timeParserPolicy", "LEGACY")

df = df.withColumn(
    "date_received",
    F.to_date(df["Date received"], "MM/dd/yy")
)

df = df.filter(df["date_received"].isNotNull())
df = df.drop("Date received")

df = df.withColumn("year", F.year("date_received"))
df = df.withColumn("month_num", F.month("date_received"))
df = df.withColumn("day", F.dayofmonth("date_received"))

print("AFTER DATE CLEANING:")
for c in df.columns:
    print(repr(c))
# Out:
# AFTER DATE CLEANING:
# 'Product'
# 'Sub-product'
# 'Issue'
# 'Sub-issue'
# 'Consumer complaint narrative'
# 'Company public response'
# 'Company'
# 'State'
# 'ZIP code'
# 'Tags'
# 'Consumer consent provided?'
# 'Submitted via'
# 'Date sent to company'
# 'Company response to consumer'
# 'Timely response?'
# 'Consumer disputed?'
# 'Complaint ID'
# 'date_received'
# 'year'
# 'month_num'
# 'day'

# %%
from pyspark.sql.functions import upper, trim

df = df.filter(df["State"].isNotNull())
df = df.filter(length(trim(col("State"))) > 0)

df = df.withColumn("State", upper(trim(col("State"))))
df = df.filter(length(col("State")) == 2)
df = df.filter(~col("State").isin("NA", "N/A", "XX", "--", "??", "00"))

print("AFTER STATE CLEANING:")
for c in df.columns:
    print(repr(c))
# Out:
# AFTER STATE CLEANING:
# 'Product'
# 'Sub-product'
# 'Issue'
# 'Sub-issue'
# 'Consumer complaint narrative'
# 'Company public response'
# 'Company'
# 'State'
# 'ZIP code'
# 'Tags'
# 'Consumer consent provided?'
# 'Submitted via'
# 'Date sent to company'
# 'Company response to consumer'
# 'Timely response?'
# 'Consumer disputed?'
# 'Complaint ID'
# 'date_received'
# 'year'
# 'month_num'
# 'day'

# %%
from pyspark.sql.functions import regexp_replace, when

df = df.withColumn("Product", upper(trim(col("Product"))))

df = df.withColumn(
    "Product",
    regexp_replace(col("Product"), "^(NA|NONE|N/A|NULL|UNSPECIFIED|\\s*)$", "")
)

df = df.withColumn(
    "Product",
    when(col("Product") == "", None).otherwise(col("Product"))
)

df = df.na.fill({"Product": "UNKNOWN"})

print("AFTER PRODUCT CLEANING:")
df.select("Product").show(10, truncate=False)
# Out:
# AFTER PRODUCT CLEANING:
# +----------------------------------------------------------------------------+
# |Product                                                                     |
# +----------------------------------------------------------------------------+
# |DEBT COLLECTION                                                             |
# |MONEY TRANSFER, VIRTUAL CURRENCY, OR MONEY SERVICE                          |
# |CREDIT REPORTING OR OTHER PERSONAL CONSUMER REPORTS                         |
# |CHECKING OR SAVINGS ACCOUNT                                                 |
# |CREDIT REPORTING OR OTHER PERSONAL CONSUMER REPORTS                         |
# |CREDIT REPORTING, CREDIT REPAIR SERVICES, OR OTHER PERSONAL CONSUMER REPORTS|
# |CREDIT REPORTING, CREDIT REPAIR SERVICES, OR OTHER PERSONAL CONSUMER REPORTS|
# |CREDIT REPORTING OR OTHER PERSONAL CONSUMER REPORTS                         |
# |DEBT COLLECTION                                                             |
# |CREDIT REPORTING OR OTHER PERSONAL CONSUMER REPORTS                         |
# +----------------------------------------------------------------------------+
# only showing top 10 rows

# %%
df = df.withColumn("Issue", upper(trim(col("Issue"))))

df = df.withColumn(
    "Issue",
    regexp_replace(col("Issue"), "^(NA|NONE|N/A|NULL|\\s*)$", "")
)

df = df.withColumn(
    "Issue",
    when(col("Issue") == "", None).otherwise(col("Issue"))
)

df = df.na.fill({"Issue": "NO_ISSUE"})

print("AFTER ISSUE CLEANING:")
df.select("Issue").show(10, truncate=False)
# Out:
# AFTER ISSUE CLEANING:
# +---------------------------------------------------+
# |Issue                                              |
# +---------------------------------------------------+
# |TOOK OR THREATENED TO TAKE NEGATIVE OR LEGAL ACTION|
# |FRAUD OR SCAM                                      |
# |INCORRECT INFORMATION ON YOUR REPORT               |
# |PROBLEM CAUSED BY YOUR FUNDS BEING LOW             |
# |IMPROPER USE OF YOUR REPORT                        |
# |IMPROPER USE OF YOUR REPORT                        |
# |INCORRECT INFORMATION ON YOUR REPORT               |
# |INCORRECT INFORMATION ON YOUR REPORT               |
# |ATTEMPTS TO COLLECT DEBT NOT OWED                  |
# |INCORRECT INFORMATION ON YOUR REPORT               |
# +---------------------------------------------------+
# only showing top 10 rows

# %%
df = df.withColumn("Sub-issue", upper(trim(col("Sub-issue"))))

df = df.withColumn(
    "Sub-issue",
    regexp_replace(col("Sub-issue"), "^(NA|NONE|N/A|NULL|\\s*)$", "")
)

df = df.withColumn(
    "Sub-issue",
    when(col("Sub-issue") == "", None).otherwise(col("Sub-issue"))
)

df = df.na.fill({"Sub-issue": "NO_SUB_ISSUE"})

print("AFTER SUB-ISSUE CLEANING:")
df.select("Sub-issue").show(10, truncate=False)
# Out:
# AFTER SUB-ISSUE CLEANING:
# +---------------------------------------------+
# |Sub-issue                                    |
# +---------------------------------------------+
# |SEIZED OR ATTEMPTED TO SEIZE YOUR PROPERTY   |
# |NO_SUB_ISSUE                                 |
# |INFORMATION BELONGS TO SOMEONE ELSE          |
# |OVERDRAFTS AND OVERDRAFT FEES                |
# |REPORTING COMPANY USED YOUR REPORT IMPROPERLY|
# |REPORTING COMPANY USED YOUR REPORT IMPROPERLY|
# |INFORMATION BELONGS TO SOMEONE ELSE          |
# |INFORMATION BELONGS TO SOMEONE ELSE          |
# |DEBT WAS PAID                                |
# |ACCOUNT INFORMATION INCORRECT                |
# +---------------------------------------------+
# only showing top 10 rows

# %%
df = df.withColumn(
    "clean_text",
    regexp_replace(
        col(text_col),
        "(?i)(x{3,}|\\*{3,}|n/?a|#|\\[redacted\\]|information provided.*)",
        ""
    )
)

df = df.withColumn("clean_text", lower(col("clean_text")))
df = df.withColumn("clean_text", regexp_replace(col("clean_text"), "[^a-zA-Z\\s]", " "))
df = df.withColumn("clean_text", regexp_replace(col("clean_text"), "\\s+", " "))
df = df.withColumn("clean_text", trim(col("clean_text")))

df = df.filter(length(col("clean_text")) > 20)

print("AFTER CLEAN TEXT:")
df.select("clean_text").show(10, truncate=False)
# Out:
# AFTER CLEAN TEXT:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |clean_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |military star card has violated my consumer rights and damaged my consumer report rating and as a consumer tural person i have recently learned my rights under title and would like the account removed pursuant to usc c a being thats it is a charge off and military star took a portion of my tax return and didnt notify me they would i believe that action was illegal and unethical to take money entitled to me and my family and i would likely have the funds returned to me and the tradeline removed from my consumer report military star card has violated my rights by sending me deceptive forms leading me to believe that i owed an alleged debt that they never once verified the account cant be verified because i am the origil creditor according to title an i do not validate this debt this account has also been a deciding factor is the cancellation of my security clearance and stopped me from gettin a new security clearance with my job which has stopped my career advancement                                                                                                                                                                                                                                                                                          |
# |on xx xx year charged for a order using a closed bank account i was not able to change the payment method within the next day i updated the payment method to and later refunded the which was routed to my balance on xx xx on xx xx removed the same from my balance through two account recovery debits and even though no valid debt existed i filed a dispute and provided proof that had been paid by other means via credit card on xx xx i received conflicting dispute results an email stating the case was decided in my favor and an in app message saying it was denied a representative told me i would receive a provisiol credit for but advised that i could not withdraw or use it and no credit was ever issued because failed to resolve the matter i disputed the recovery transaction with my bank after which froze and suspended my account and issued a debt notice i then submitted a formal dispute to the dispute department on xx xx began sending additiol notices claiming i now owed double the origil transaction despite the fact that had already refunded the order and i provided proof of alterte payment                                                                                                                                                               |
# |dear cfpb i am sending to dispute fraudulent items on my credit reports which have resulted from identity theft these items were opened without my authorization or consent and their reporting violates multiple provisions of u s law including the fair credit reporting act fcra these items in question are high balance account number date xx xx duration years origil creditor high balance account number date xx xx duration years high balance account number date xx xx duration years xx xx                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |i am writing to file a complaint against vy federal credit union regarding multiple over draft fees i incurred despite having sufficient funds when transactions were authorized i was charged fees due to lagged posting of charges and credits this issue aligns with the recent cfpb findings against vy federal for similar practices where transactions settled with insufficient balances despite initially available funds i believe these practices are unfair and request an investigation into my account transactions                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |these companies are in clear violation of the law under u s code b permissible purposes of consumer reports the law clearly states u s code s responsibilities of furnishers of information to consumer reporting agencies a duty of furnishers of information to provide accurate information prohibition a reporting information with actual knowledge of errors a person shall not furnish any information relating to a consumer to any consumer reporting agency if the person knows or has reasoble cause to believe that the information is iccurate acct dates xx xx xx xx acct dates xx xx these companies are also in clear violation of another law under u s code b a timing of payments the law clearly states a time to make payments a creditor may not treat a payment on a credit card account under an open end consumer credit plan as late for any purpose unless the creditor has adopted reasoble procedures designed to ensure that each periodic statement including the information required by section b of this title is mailed or delivered to the consumer not later than days before the payment due date i have not received any information under section b sent to me certified mail within days before the payment due date which puts this company in violation of this law|
# |the list of inquries listed below are a result of indenity theft i did not give premission to have my credit ran by these company i have rights and they have been broken please remove and send me how you investigate these inquries thanks community credit on xx xx equifax mortgage services on xx xx on xx xx on xx xx please remove                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |this is my numerous request that i have been a victim of identity theft and that no one seems to care that i want to dispute specific records in my credit file that do not belong to me or that i have signed any agreement the items i m challenging have nothing to do with any transactions i ve done or authorized to gain products services or money please remove the following items ca xx xx balance xx xx xx xx                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |upon reviewing my credit report i have identified iccurate accounts that need reporting and correction through your company                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |this is not my account i have no idea who this person is or what this company is i called it says its a collection agency but they cant find my info whn i call and i have never owed money to any one it says i was in collection they are not my account nor are they a credit reporting facility they are not a credit card and i have no collections notices or any kind of communication this is not my account remove it now it says paid and closed then remove it as it is hurting my report and it is not my information delete now                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |my credit report should only reflect accurate information which is why its important to verify the accuracy of this data rather than relying solely on what the data furnisher has provided its frustrating to see my credit get negatively affected by iccuracies that arent my fault i m deeply concerned about these errors and they ve been causing me stress and it s also impacting my ability to secure new credit they are mixed fraudulent information that ive never authorized or benefited from if you can not certify that all data belongs to me these accounts and its respective charges must be removed entirely and i need you to address this as soon as possible to prevent further damage                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
print("FINAL COLUMNS:")
for c in df.columns:
    print(repr(c))

df.printSchema()
df.show(5, truncate=120)

spark.conf.set("spark.sql.parquet.datetimeRebaseModeInWrite", "LEGACY")

df.write.mode("overwrite").parquet(data_path + "cleaned_data.parquet")
print("CLEANED DATA SAVED.")
# Out:
# FINAL COLUMNS:
# 'Product'
# 'Sub-product'
# 'Issue'
# 'Sub-issue'
# 'Consumer complaint narrative'
# 'Company public response'
# 'Company'
# 'State'
# 'ZIP code'
# 'Tags'
# 'Consumer consent provided?'
# 'Submitted via'
# 'Date sent to company'
# 'Company response to consumer'
# 'Timely response?'
# 'Consumer disputed?'
# 'Complaint ID'
# 'date_received'
# 'year'
# 'month_num'
# 'day'
# 'clean_text'
# root
#  |-- Product: string (nullable = false)
#  |-- Sub-product: string (nullable = true)
#  |-- Issue: string (nullable = false)
#  |-- Sub-issue: string (nullable = false)
#  |-- Consumer complaint narrative: string (nullable = true)
#  |-- Company public response: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIP code: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Consumer consent provided?: string (nullable = true)
#  |-- Submitted via: string (nullable = true)
#  |-- Date sent to company: string (nullable = true)
#  |-- Company response to consumer: string (nullable = true)
#  |-- Timely response?: string (nullable = true)
#  |-- Consumer disputed?: string (nullable = true)
#  |-- Complaint ID: string (nullable = true)
#  |-- date_received: date (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month_num: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- clean_text: string (nullable = true)
#
# +---------------------------------------------------+----------------------------+---------------------------------------------------+---------------------------------------------+------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------+-----+--------+-------------+--------------------------+-------------+--------------------+-------------------------------+----------------+------------------+------------+-------------+----+---------+---+------------------------------------------------------------------------------------------------------------------------+
# |                                            Product|                 Sub-product|                                              Issue|                                    Sub-issue|                                                                                            Consumer complaint narrative|                                                                        Company public response|                               Company|State|ZIP code|         Tags|Consumer consent provided?|Submitted via|Date sent to company|   Company response to consumer|Timely response?|Consumer disputed?|Complaint ID|date_received|year|month_num|day|                                                                                                              clean_text|
# +---------------------------------------------------+----------------------------+---------------------------------------------------+---------------------------------------------+------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------+-----+--------+-------------+--------------------------+-------------+--------------------+-------------------------------+----------------+------------------+------------+-------------+----+---------+---+------------------------------------------------------------------------------------------------------------------------+
# |                                    DEBT COLLECTION|            Credit card debt|TOOK OR THREATENED TO TAKE NEGATIVE OR LEGAL ACTION|   SEIZED OR ATTEMPTED TO SEIZE YOUR PROPERTY|Military star card has violated my consumer rights and damaged my consumer report rating and as a consumer/natural pe...|Company has responded to the consumer and the CFPB and chooses not to provide a public response|   Army and Air Force Exchange Service|   TX|   761XX|Servicemember|          Consent provided|          Web|            06/27/21|        Closed with explanation|              No|               N/A|     4496008|   2021-06-27|2021|        6| 27|military star card has violated my consumer rights and damaged my consumer report rating and as a consumer tural pers...|
# | MONEY TRANSFER, VIRTUAL CURRENCY, OR MONEY SERVICE|Domestic (US) money transfer|                                      FRAUD OR SCAM|                                 NO_SUB_ISSUE|On XX/XX/year>, XXXX  charged {$20.00} for a XXXX order using a closed bank account. I was not able to change the pay...|                                                                                           None|                  Paypal Holdings, Inc|   CT|   064XX|         None|          Consent provided|          Web|            09/10/25|Closed with non-monetary relief|             Yes|               N/A|    15812229|   2025-09-09|2025|        9|  9|on xx xx year charged for a order using a closed bank account i was not able to change the payment method within the ...|
# |CREDIT REPORTING OR OTHER PERSONAL CONSUMER REPORTS|            Credit reporting|               INCORRECT INFORMATION ON YOUR REPORT|          INFORMATION BELONGS TO SOMEONE ELSE|Dear CFPB, I am sending to dispute fraudulent items on my credit reports, which have resulted from identity theft. Th...|Company has responded to the consumer and the CFPB and chooses not to provide a public response|TRANSUNION INTERMEDIATE HOLDINGS, INC.|   FL|   33578|         None|          Consent provided|          Web|            08/04/25|        Closed with explanation|             Yes|               N/A|    15013629|   2025-08-04|2025|        8|  4|dear cfpb i am sending to dispute fraudulent items on my credit reports which have resulted from identity theft these...|
# |                        CHECKING OR SAVINGS ACCOUNT|            Checking account|             PROBLEM CAUSED BY YOUR FUNDS BEING LOW|                OVERDRAFTS AND OVERDRAFT FEES|I am writing to file a complaint against navy federal credit union regarding multiple over draft fees I incurred. Des...|                       Company believes it acted appropriately as authorized by contract or law|             NAVY FEDERAL CREDIT UNION|   NY|   14215|         None|          Consent provided|          Web|            01/19/25|        Closed with explanation|             Yes|               N/A|    11623116|   2025-01-19|2025|        1| 19|i am writing to file a complaint against vy federal credit union regarding multiple over draft fees i incurred despit...|
# |CREDIT REPORTING OR OTHER PERSONAL CONSUMER REPORTS|            Credit reporting|                        IMPROPER USE OF YOUR REPORT|REPORTING COMPANY USED YOUR REPORT IMPROPERLY|These companies are in clear violation of the law. Under 15 U.S. Code 1681b - Permissible purposes of consumer report...|                                                                                           None|                         EQUIFAX, INC.|   NC|   28278|         None|          Consent provided|          Web|            04/10/24|        Closed with explanation|             Yes|               N/A|     8740050|   2024-04-10|2024|        4| 10|these companies are in clear violation of the law under u s code b permissible purposes of consumer reports the law c...|
# +---------------------------------------------------+----------------------------+---------------------------------------------------+---------------------------------------------+------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------+-----+--------+-------------+--------------------------+-------------+--------------------+-------------------------------+----------------+------------------+------------+-------------+----+---------+---+------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
# CLEANED DATA SAVED.
